# %% [markdown]
# <a href="https://colab.research.google.com/github/Niyaz-007/Data-science-/blob/main/untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4,5]
y=[2,4,6,8,10]

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

month=["jan","feb","mar","apr","may"]
sales=[20,30,25,40,50]

plt.plot(month,sales)
plt.show()

# %%
import matplotlib.pyplot as plt

month =["jan","feb","mar","apr","may"]

sales =[20,30,25,40,50]
profit =[5,8,6,12,15]

plt.plot(months,sales,label="sales") #there label means name the label
plt.plot(month,profit,label="profit")
plt.legend() #it means display the names

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3496/4045058149.py in <cell line: 0>()
#       6 profit =[5,8,6,12,15]
#       7
# ----> 8 plt.plot(months,sales,label="sales") #there label means name the label
#       9 plt.plot(month,profit,label="profit")
#      10 plt.legend() #it means display the names
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.13/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
# ...

# %%
import matplotlib.pyplot as plt

months=["jan","feb","mar","apr","may","jun","jul"]
sales=[20,30,25,40,50,80,10]
plt.plot(months,sales)


plt.xlabel("months")
plt.ylabel("sales")
plt.title("monthly sales")
plt.grid(True)
plt.plot(months,sales,marker="+",color="red",linestyle="-")
plt.show()

# %%
import matplotlib.pyplot as plt

months=["jan","feb","mar","apr","may","jun","jul"]
sales=[20,30,25,40,50,80,10]
plt.bar(months,sales)


plt.xlabel("months")
plt.ylabel("sales")
plt.title("monthly sales")
plt.grid(True)
plt.show()

# %%
study_hours=["jan","feb","mar","apr","may",]

marks=[20,30,25,40,50]
plt.scatter(study_hours,marks)

plt.title("study_hours vs marks")
plt.xlabel("study_hours")
plt.ylabel("marks")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = np.random.randn(1000)
plt.figure(figsize=(8,6))
sns.histplot(data,bins=30,kde=True,color='skyblue',edgecolor='black')
plt.xlabel('value')
plt.ylabel('frequency')
plt.title('distribution of random data using seaborn')
plt.grid(axis='y',alpha=0.75)
plt.show()

# %%
from matplotlib.lines import lineStyles
months=["jan","feb","mar","apr"]
sales=[20,30,40,50]
plt.plot(months,sales,marker="^",linestyle="-.")
plt.xlabel("months")
plt.ylabel("sales")
plt.title("sales per month")
plt.grid(True)
plt.show()

# %%
products=["pen","ben","men","zen"]
sales=[20,30,40,50]
plt.barh(products,sales)
plt.xlabel("products")
plt.ylabel("sales")
plt.title("product sales")
plt.show()

# %%
x=[3,5,7,9,10]
y=[2,4,5,6,10]
plt.plot(x,y)
plt.fill_between(x,y)
plt.show()

# %%
marks=[34,56,78,85,90,55,67,89]
sns.boxplot(x=marks)
plt.show()

# %%
sales=[
    [10,20,30,40],
    [15,25,35,45],
    [20,30,40,50]
]
sns.heatmap(sales, annot=True, cmap="Purples")

plt.show()
